# %%
import pandas as pd

print("Hi! This is a cell. Press the ▶ button above to run it")
# Out:
# Hi! This is a cell. Press the ▶ button above to run it

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
fixed_df = pd.read_csv(r'C:\Users\Lenovo\Downloads\bikes - Sheet1.csv', 
                       encoding='utf-8', parse_dates=['Date'], dayfirst=True,
                       index_col='Date')
fixed_df[:10]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-02-01       83                                NaN                      1
# 2012-03-01      135                                NaN                      2
# 2012-04-01       56                                NaN                      8
# 2012-05-01       14                                NaN                      0
# 2012-06-01       25                                NaN                     13
# 2012-07-01      138                                NaN                      5
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy\t  Rachel1  \
# Date
# 2012-01-01             38             51       26              10       16
# 2012-02-01             68            153       53               6       43
# 2012-03-01            104            248       89               3       58
# 2012-04-01             34             23       25               2       36
# 2012-05-01             55             76       69               8       78
# 2012-06-01             76            128      111               7       75
# 2012-07-01            215            334      179              12      112
#
#             St-Urbain (données non disponibles)\t\t\t\t\t\t\t
# Date
# 2012-01-01                                                NaN
# 2012-02-01                                                NaN
# 2012-03-01                                                NaN
# 2012-04-01                                                NaN
# 2012-05-01                                                NaN
# 2012-06-01                                                NaN
# 2012-07-01                                                NaN

# %%
fixed_df['Berri 1'][:10]
# Out:
# Date
# 2012-01-01     35
# 2012-02-01     83
# 2012-03-01    135
# 2012-04-01     56
# 2012-05-01     14
# 2012-06-01     25
# 2012-07-01    138
# Name: Berri 1, dtype: int64

# %%
fixed_df['Berri 1'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fixed_df.plot(figsize=(15, 10))
# Out:
# <Axes: xlabel='Date'>
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
